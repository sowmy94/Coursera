# %%
from flask import Flask
app=Flask(__name__)
@app.route("/")
def home():
    return {"message": "Hello World"}

if __name__ == "__main__":
   app.run(debug=False, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Mar/2026 10:21:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Mar/2026 10:21:30] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Mar/2026 10:21:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Mar/2026 10:21:54] "GET /favicon.ico HTTP/1.1" 404 -
