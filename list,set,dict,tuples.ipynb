# %%
albums_list = [
    {"Artist": "Michael Jackson", "Album": "Thriller", "Year": 1982, "Length": "00:42:19",
     "Genre": "Pop, rock, R&B", "Music_recording_sales_millions": 46.0, "Claimed_sales_millions": 65.0,
     "Release_date": "30-Nov-82", "Soundtrack": False, "Rating_friends": 10.0},

    {"Artist": "AC/DC", "Album": "Back in Black", "Year": 1980, "Length": "00:42:11",
     "Genre": "Hard rock", "Music_recording_sales_millions": 26.1, "Claimed_sales_millions": 50.0,
     "Release_date": "25-Jul-80", "Soundtrack": False, "Rating_friends": 8.5},

    {"Artist": "Pink Floyd", "Album": "The Dark Side of the Moon", "Year": 1973, "Length": "00:42:49",
     "Genre": "Progressive rock", "Music_recording_sales_millions": 24.2, "Claimed_sales_millions": 45.0,
     "Release_date": "01-Mar-73", "Soundtrack": False, "Rating_friends": 9.5},

    {"Artist": "Whitney Houston", "Album": "The Bodyguard", "Year": 1992, "Length": "00:57:44",
     "Genre": "Soundtrack/R&B, soul, pop", "Music_recording_sales_millions": 26.1, "Claimed_sales_millions": 50.0,
     "Release_date": "25-Jul-80", "Soundtrack": True, "Rating_friends": 7.0},

    {"Artist": "Meat Loaf", "Album": "Bat Out of Hell", "Year": 1977, "Length": "00:46:33",
     "Genre": "Hard rock, progressive rock", "Music_recording_sales_millions": 20.6, "Claimed_sales_millions": 43.0,
     "Release_date": "21-Oct-77", "Soundtrack": False, "Rating_friends": 7.0},

    {"Artist": "Eagles", "Album": "Their Greatest Hits (1971-1975)", "Year": 1976, "Length": "00:43:08",
     "Genre": "Rock, soft rock, folk rock", "Music_recording_sales_millions": 32.2, "Claimed_sales_millions": 42.0,
     "Release_date": "17-Feb-76", "Soundtrack": False, "Rating_friends": 9.5},

    {"Artist": "Bee Gees", "Album": "Saturday Night Fever", "Year": 1977, "Length": "1:15:54",
     "Genre": "Disco", "Music_recording_sales_millions": 20.6, "Claimed_sales_millions": 40.0,
     "Release_date": "15-Nov-77", "Soundtrack": True, "Rating_friends": 9.0},

    {"Artist": "Fleet wood Mac", "Album": "Rumours", "Year": 1977, "Length": "00:40:01",
     "Genre": "Soft rock", "Music_recording_sales_millions": 27.9, "Claimed_sales_millions": 40.0,
     "Release_date": "04-Feb-77", "Soundtrack": False, "Rating_friends": 9.5},
]
print (albums_list)
# Out:
# [{'Artist': 'Michael Jackson', 'Album': 'Thriller', 'Year': 1982, 'Length': '00:42:19', 'Genre': 'Pop, rock, R&B', 'Music_recording_sales_millions': 46.0, 'Claimed_sales_millions': 65.0, 'Release_date': '30-Nov-82', 'Soundtrack': False, 'Rating_friends': 10.0}, {'Artist': 'AC/DC', 'Album': 'Back in Black', 'Year': 1980, 'Length': '00:42:11', 'Genre': 'Hard rock', 'Music_recording_sales_millions': 26.1, 'Claimed_sales_millions': 50.0, 'Release_date': '25-Jul-80', 'Soundtrack': False, 'Rating_friends': 8.5}, {'Artist': 'Pink Floyd', 'Album': 'The Dark Side of the Moon', 'Year': 1973, 'Length': '00:42:49', 'Genre': 'Progressive rock', 'Music_recording_sales_millions': 24.2, 'Claimed_sales_millions': 45.0, 'Release_date': '01-Mar-73', 'Soundtrack': False, 'Rating_friends': 9.5}, {'Artist': 'Whitney Houston', 'Album': 'The Bodyguard', 'Year': 1992, 'Length': '00:57:44', 'Genre': 'Soundtrack/R&B, soul, pop', 'Music_recording_sales_millions': 26.1, 'Claimed_sales_millions': 50.0, 'Release_d
# ...

# %%
albums_list[3:5]
# Out:
# [{'Artist': 'Whitney Houston',
#   'Album': 'The Bodyguard',
#   'Year': 1992,
#   'Length': '00:57:44',
#   'Genre': 'Soundtrack/R&B, soul, pop',
#   'Music_recording_sales_millions': 26.1,
#   'Claimed_sales_millions': 50.0,
#   'Release_date': '25-Jul-80',
#   'Soundtrack': True,
#   'Rating_friends': 7.0},
#  {'Artist': 'Meat Loaf',
#   'Album': 'Bat Out of Hell',
#   'Year': 1977,
#   'Length': '00:46:33',
#   'Genre': 'Hard rock, progressive rock',
#   'Music_recording_sales_millions': 20.6,
#   'Claimed_sales_millions': 43.0,
#   'Release_date': '21-Oct-77',
#   'Soundtrack': False,
#   'Rating_friends': 7.0}]

# %%
albums_list.extend([{'Artist': 'Artist Name', 
                     'Album': 'Album Name', 'Year': 2000,
                       'Length': '00:00:00', 'Genre': 'pop',
                         'Music_recording_sales_millions': 10.0, 
                         'Claimed_sales_millions': 10.0, 'Release_date': '01-Jan-00', 
                         'Soundtrack': False, 'Rating_friends': 10.0}])
print(albums_list)
# Out:
# [{'Artist': 'Michael Jackson', 'Album': 'Thriller', 'Year': 1982, 'Length': '00:42:19', 'Genre': 'Pop, rock, R&B', 'Music_recording_sales_millions': 46.0, 'Claimed_sales_millions': 65.0, 'Release_date': '30-Nov-82', 'Soundtrack': False, 'Rating_friends': 10.0}, {'Artist': 'AC/DC', 'Album': 'Back in Black', 'Year': 1980, 'Length': '00:42:11', 'Genre': 'Hard rock', 'Music_recording_sales_millions': 26.1, 'Claimed_sales_millions': 50.0, 'Release_date': '25-Jul-80', 'Soundtrack': False, 'Rating_friends': 8.5}, {'Artist': 'Pink Floyd', 'Album': 'The Dark Side of the Moon', 'Year': 1973, 'Length': '00:42:49', 'Genre': 'Progressive rock', 'Music_recording_sales_millions': 24.2, 'Claimed_sales_millions': 45.0, 'Release_date': '01-Mar-73', 'Soundtrack': False, 'Rating_friends': 9.5}, {'Artist': 'Whitney Houston', 'Album': 'The Bodyguard', 'Year': 1992, 'Length': '00:57:44', 'Genre': 'Soundtrack/R&B, soul, pop', 'Music_recording_sales_millions': 26.1, 'Claimed_sales_millions': 50.0, 'Release_d
# ...

# %%
# show new length and last item added
print("length:", len(albums_list))
print("last item:", albums_list[-1])
# Out:
# length: 10
# last item: {'Artist': 'Artist Name', 'Album': 'Album Name', 'Year': 2000, 'Length': '00:00:00', 'Genre': 'pop', 'Music_recording_sales_millions': 10.0, 'Claimed_sales_millions': 10.0, 'Release_date': '01-Jan-00', 'Soundtrack': False, 'Rating_friends': 10.0}

# %%
L = [ "The Bodyguard", 7.0]
L.extend(['pop', 10])
print(L)   
print(len(L))
# Out:
# ['The Bodyguard', 7.0, 'pop', 10]
# 4

# %%
L.append(['doodle', 10])
L
# Out:
# ['The Bodyguard', 7.0, 'pop', 10, ['doodle', 10]]

# %%
A = ["disco", 10, 1.2]
print('Before change:', A)
A[0] = 'hard rock'
print('After change:', A)
# Out:
# Before change: ['disco', 10, 1.2]
# After change: ['hard rock', 10, 1.2]

# %%
print('Before change:', A)
del(A[0])
print('After change:', A)
# Out:
# Before change: ['hard rock', 10, 1.2]
# After change: [10, 1.2]

# %%
'hard rock'.split()
# Out:
# ['hard', 'rock']

# %%
'a,b,c,d'.split(',')
# Out:
# ['a', 'b', 'c', 'd']

# %%
A = ["hard rock", 10, 1.2]
B = A
print('A:', A)
print('B:', B)
print('B[0]:', B[0])
A[0] = "banana"
print('B[0]:', B[0])
# Out:
# A: ['hard rock', 10, 1.2]
# B: ['hard rock', 10, 1.2]
# B[0]: hard rock
# B[0]: banana

# %%
a_list = [1,'hello',[1,2,3,],True]
a_list
# Out:
# [1, 'hello', [1, 2, 3], True]

# %%
a_list[1]
a_list[1:4]
# Out:
# ['hello', [1, 2, 3], True]

# %%
tuple1 = ("disco",10,1.2 )
tuple1
type(tuple1)
# Out:
# tuple

# %%
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(type(tuple1[0]))
print(type(tuple1[1]))
print(type(tuple1[2]))
# Out:
# disco
# 10
# 1.2
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
tuple2 = tuple1 + ("hard rock", 10)
tuple2
# Out:
# ('disco', 10, 1.2, 'hard rock', 10)

# %%
Ratings = (0, 9, 6, 5, 10, 8, 9, 6, 2)
print(sorted(Ratings))
# Out:
# [0, 2, 5, 6, 6, 8, 9, 9, 10]

# %%
NestedT =(1, 2, ("pop", "rock") ,(3,4),("disco",(1,2)))

# %%
print("Element 0 of Tuple: ", NestedT[0])
print("Element 1 of Tuple: ", NestedT[1])
print("Element 2 of Tuple: ", NestedT[2])
print("Element 3 of Tuple: ", NestedT[3])
print("Element 4 of Tuple: ", NestedT[4])
# Out:
# Element 0 of Tuple:  1
# Element 1 of Tuple:  2
# Element 2 of Tuple:  ('pop', 'rock')
# Element 3 of Tuple:  (3, 4)
# Element 4 of Tuple:  ('disco', (1, 2))

# %%
print("Element 2, 0 of Tuple: ",   NestedT[2][0])
print("Element 2, 1 of Tuple: ",   NestedT[2][1])
print("Element 3, 0 of Tuple: ",   NestedT[3][0])
print("Element 3, 1 of Tuple: ",   NestedT[3][1])
print("Element 4, 0 of Tuple: ",   NestedT[4][0])
print("Element 4, 1 of Tuple: ",   NestedT[4][1])
# Out:
# Element 2, 0 of Tuple:  pop
# Element 2, 1 of Tuple:  rock
# Element 3, 0 of Tuple:  3
# Element 3, 1 of Tuple:  4
# Element 4, 0 of Tuple:  disco
# Element 4, 1 of Tuple:  (1, 2)

# %%
NestedT[2][1][0]
# Out:
# 'r'

# %%
Dict = {"key1": 1, "key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), ('key5'): 5, (0, 1): 6}
Dict
# Out:
# {'key1': 1,
#  'key2': '2',
#  'key3': [3, 3, 3],
#  'key4': (4, 4, 4),
#  'key5': 5,
#  (0, 1): 6}

# %%
Dict["key1"]
# Out:
# 1

# %%
Dict[(0, 1)]
# Out:
# 6

# %%
release_year_dict = {"Thriller": "1982", "Back in Black": "1980", \
                    "The Dark Side of the Moon": "1973", "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}
release_year_dict
# Out:
# {'Thriller': '1982',
#  'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977'}

# %%
release_year_dict['Thriller']
# Out:
# '1982'

# %%
release_year_dict.keys()
# Out:
# dict_keys(['Thriller', 'Back in Black', 'The Dark Side of the Moon', 'The Bodyguard', 'Bat Out of Hell', 'Their Greatest Hits (1971-1975)', 'Saturday Night Fever', 'Rumours'])

# %%
release_year_dict['Graduation'] = '2007'
release_year_dict
# Out:
# {'Thriller': '1982',
#  'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977',
#  'Graduation': '2007'}

# %%
del(release_year_dict['Thriller'])
del(release_year_dict['Graduation'])
release_year_dict
# Out:
# {'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977'}

# %%
inventory ={}

# %%
ProductNo1 = "Mobile Phone"
ProductNo1_quantity = 5
ProductNo1_price = 20000
ProductNo1_releaseYear= 2020

# %%
inventory
# Out:
# {}

# %%
inventory["ProductNo1"]= ProductNo1
inventory["ProductNo1_quantity"]= ProductNo1_quantity
inventory["ProductNo1_price"]= ProductNo1_price
inventory["ProductNo1_releaseYear"]=ProductNo1_releaseYear
print(inventory)
# Out:
# {'ProductNo1': 'Mobile Phone', 'ProductNo1_quantity': 5, 'ProductNo1_price': 20000, 'ProductNo1_releaseYear': 2020}

# %%
set1 = {"pop", "rock", "soul", "hard rock", "rock", "R&B", "rock", "disco"}
set1
# Out:
# {'R&B', 'disco', 'hard rock', 'pop', 'rock', 'soul'}

# %%
album_list = [ "Michael Jackson", "Thriller", 1982, "00:42:19", \
              "Pop, Rock, R&B", 46.0, 65, "30-Nov-82", None, 10.0]
album_set = set(album_list)             
album_set
# Out:
# {'00:42:19',
#  10.0,
#  1982,
#  '30-Nov-82',
#  46.0,
#  65,
#  'Michael Jackson',
#  None,
#  'Pop, Rock, R&B',
#  'Thriller'}

# %%
# Sample set

A = set(["Thriller", "Back in Black", "AC/DC"])
A
# Out:
# {'AC/DC', 'Back in Black', 'Thriller'}

# %%
A.add("NSYNC")
A
# Out:
# {'AC/DC', 'Back in Black', 'NSYNC', 'Thriller'}

# %%
"AC/DC" in A
# Out:
# True

# %%
album_set1 = set(["Thriller", 'AC/DC', 'Back in Black'])
album_set2 = set([ "AC/DC", "Back in Black", "The Dark Side of the Moon"])

# %%
# Print two sets

album_set1, album_set2
# Out:
# ({'AC/DC', 'Back in Black', 'Thriller'},
#  {'AC/DC', 'Back in Black', 'The Dark Side of the Moon'})

# %%
# Find the intersections

intersection = album_set1 & album_set2
intersection
# Out:
# {'AC/DC', 'Back in Black'}

# %%
# Find the difference in set1 but not set2

album_set1.difference(album_set2)
# Out:
# {'Thriller'}

# %%
# Find the union of two sets

album_set1.union(album_set2)
# Out:
# {'AC/DC', 'Back in Black', 'The Dark Side of the Moon', 'Thriller'}

# %%
# Check if superset

set(album_set1).issuperset(album_set2)
# Out:
# False

# %%
# Elif statment example

age = 18

if age > 18:
    print("you can enter" )
elif age == 18:
    print("go see Pink Floyd")
else:
    print("go see Meat Loaf" )
    
print("move on")
# Out:
# go see Pink Floyd
# move on

# %%
# Condition statement example

album_year = 1980

if(album_year > 1979) and (album_year < 1990):
    print ("Album year was in between 1980 and 1989")
    
print("")
print("Do Stuff..")
# Out:
# Album year was in between 1980 and 1989
#
# Do Stuff..
