# %%
print('Hello, Python!')
# Out:
# Hello, Python!

# %%
import sys
print(sys.version)
# Out:
# 3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]

# %%
#int
a = 10
print(a)
# Out:
# 10

# %%
#float
b = 3.14
print(b)

#string
c = "Hello, World!"
print(c)
#boolean
d = True            
print(d)
# Out:
# 3.14
# Hello, World!
# True

# %%
type(a)  # Output: <class 'int'>
type(b)  # Output: <class 'float'>          
type(c)  # Output: <class 'str'>
type(d)  # Output: <class 'bool'>
# Out:
# bool

# %%
float(a)  # Output: 10.0
str(a)

int(b)
str(b)

#int(c)  # This will raise a ValueError
#float(c)  # This will also raise a ValueError           

int(d)  # Output: 1
float(d)  # Output: 1.0
str(d)  # Output: 'True'

int(3.88)  # Output: 3
round(3.88)  # Output: 4.0
round(3.88, 1)  # Output: 3.9
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 7
#       4 int(b)
#       5 str(b)
# ----> 7 int(c)  # This will raise a ValueError
#       8 float(c)  # This will also raise a ValueError
#      10 int(d)  # Output: 1
#
# ValueError: invalid literal for int() with base 10: 'Hello, World!'

# %%
type(6/2)

type(6//2)
# Out:
# int

# %%
str(123-456-7890)
# Out:
# '-8223'

# %%
float("1234.56")
# Out:
# 1234.56

# %%
type("hello" == "world") 

type(10 > 5)
type(10 < 5)
type(10 == 10)
# Out:
# bool

# %%
11//2
# Out:
# 5

# %%
x=4

x=x/2
print(x)
# Out:
# 2.0

# %%
a = "The BodyGuard"
print(a)
# Out:
# The BodyGuard

# %%
a='The BodyGuard is a movie'
print(a)
# Out:
# The BodyGuard is a movie

# %%
'1 2 3 4 5 6 '
# Out:
# '1 2 3 4 5 6 '

# %%
'@#2_#]&*^%$'
# Out:
# '@#2_#]&*^%$'

# %%
print(a[0])
# Out:
# T

# %%
print(a[10])
# Out:
# a

# %%
print(a[-1 ])
# Out:
# e

# %%
len(a)
# Out:
# 24

# %%
a[0:13]
# Out:
# 'The BodyGuard'

# %%
a[14:24]
# Out:
# 'is a movie'

# %%
a[::2]
# Out:
# 'TeBdGadi  oi'

# %%
a[0:13:2]
# Out:
# 'TeBdGad'

# %%
print(" The BodyGuard\n is the best album" )
print(" The BodyGuard\t is the best album" )
print(" The BodyGuard\\ is the best album" )
print(r" The BodyGuard \ is the best album" )
# Out:
#  The BodyGuard
#  is the best album
#  The BodyGuard	 is the best album
#  The BodyGuard\ is the best album
#  The BodyGuard \ is the best album

# %%
"helloMike".find("Mike")
# Out:
# 5

# %%
a = "Thriller is the sixth studio album"
print("before upper:", a)
b = a.upper()
print("After upper:", b)
# Out:
# before upper: Thriller is the sixth studio album
# After upper: THRILLER IS THE SIXTH STUDIO ALBUM

# %%
name = "The BodyGuard"
name.find('he')
# Out:
# 1

# %%
name = "The BodyGuard"
name.find('Guard')
# Out:
# 8

# %%
name.find('Jasdfasdasdf')
# Out:
# -1

# %%
name = "The BodyGuard"
split_string = (name.split())
split_string
# Out:
# ['The', 'BodyGuard']

# %%
import re

# %%
s1 = "The BodyGuard is the best album"

# Define the pattern to search for
pattern = r"Body"

# Use the search() function to search for the pattern in the string
result = re.search(pattern, s1)

# Check if a match was found
if result:
    print("Match found!")
else:
    print("Match not found.")
# Out:
# Match found!

# %%
pattern = r"\W"  # Matches any non-word character
text = "Hello, world!"
matches = re.findall(pattern, text)

print("Matches:", matches)
# Out:
# Matches: [',', ' ', '!']

# %%
s2 = "The BodyGuard is the best album of 'Whitney Houston'."


# Use the findall() function to find all occurrences of the "st" in the string
result = re.findall("st", s2)

# Print out the list of matched words
print(result)
# Out:
# ['st', 'st']

# %%
# Define the regular expression pattern to search for
pattern = r"Whitney Houston"

# Define the replacement string
replacement = "legend"

# Use the sub function to replace the pattern with the replacement string
new_string = re.sub(pattern, replacement, s2, flags=re.IGNORECASE) # re.IGNORECASE makes the search case-insensitive, so it matches "Whitney Houston" in any letter case

# The new_string contains the original string with the pattern replaced by the replacement string
print(new_string)
# Out:
# The BodyGuard is the best album of 'legend'.
